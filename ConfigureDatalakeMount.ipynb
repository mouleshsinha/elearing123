# %%
dbutils.fs.mkdirs("/mnt/mountdatalake")  

configs = {"dfs.adls.oauth2.access.token.provider.type": "ClientCredential",
             "dfs.adls.oauth2.client.id": "61434c42-342b-4056-8652-9026a2656cde",
             "dfs.adls.oauth2.credential": "6tIzn4FiYeuKSJJ/WfzUiD9fmpET4NsKYGzw+0hGmkQ=",
             "dfs.adls.oauth2.refresh.url": "https://login.microsoftonline.com/YOUR_DIRECTORY_ID/oauth2/token"}

dbutils.fs.mount(
    source = "adl://ispdata.azuredatalakestore.net/mountdatabricks",
    mount_point = "/mnt/mountdatalake",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>True
# </div>
