# %%
from pyspark.sql import *
import pandas as pd

jdbcHostname = "dbrickssqlsrvr.database.windows.net"
jdbcPort = "1433"
jdbcDatabase = "dbrickssql"
properties = {
        "user": "dbricksadmin",
        "password": "Password@123"
    }
url = "jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname, jdbcPort, jdbcDatabase)


pushdown_query = "(select * from dbo.sales) as sales"
print(pushdown_query)

#Read from SQL database
df2 = spark.read.jdbc(url=url, table=pushdown_query, properties=properties)

#Write to a datalake
df2.toPandas().to_csv('/dbfs/mnt/mountdatalake/sales.csv', header='True', encoding="utf-8")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(select * from dbo.sales) as sales
# </div>
