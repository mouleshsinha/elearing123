# %%
from pyspark.sql import *
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mountdatabricksjdbcHostname = "dbrickssqlsrvr.database.windows.net"
jdbcPort = "1433"
jdbcDatabase = "dbrickssql"
properties = {
        "user": "dbricksadmin",
        "password": "Password@123"
    }
url = "jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname, jdbcPort, jdbcDatabase)
filedf = sqlContext.read.csv("/FileStore/tables/BDCS_DIY_Sales-bd339.csv", header=True)

filedf = filedf.withColumnRenamed("_c0", "id")
filedf1 = DataFrameWriter(filedf)
filedf1.jdbc(url=url, table="sales", mode="overwrite", properties=properties)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(select * from dbo.sales) as sales
# </div>
